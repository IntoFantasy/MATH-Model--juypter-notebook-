# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import sklearn.datasets as ds
import matplotlib.colors
from sklearn.cluster import KMeans#引入kmeans

## 设置属性防止中文乱码
mpl.rcParams['font.sans-serif'] = [u'SimHei']
mpl.rcParams['axes.unicode_minus'] = False

# %%
N = 1500      # 样本数
centers = 4   # 聚类中心个数
# 生成两组数据
data, y = ds.make_blobs(n_samples=N, n_features=2, centers=centers, random_state=28)
data2, y2 = ds.make_blobs(n_samples=N, n_features=2, centers=centers, random_state=28)
print(data)
print(y)
# Out:
# [[ 4.60963752  0.48020169]
#  [-6.90563049 -0.62838152]
#  [ 6.02200924 -0.42255227]
#  ...
#  [-8.13583711 -2.89528592]
#  [ 6.20079698 -0.06480641]
#  [ 4.65785457  0.26529753]]
# [0 1 2 ... 1 2 0]

# %% [markdown]
# ![make_blobs](picture/make_blobs.png)

# %%
km = KMeans(n_clusters=centers, init='random', random_state=28)
km.fit(data, y)
# Out:
# KMeans(init='random', n_clusters=4, random_state=28)

# %%
cm = mpl.colors.ListedColormap(list('rgbmyc'))
plt.figure(figsize=(15, 9), facecolor='w')
plt.scatter(data[:, 0], data[:, 1], c=y, s=30, cmap='coolwarm', edgecolors='none')

# %%
y_hat = km.predict(data)
print(y_hat)
# Out:
# [3 0 1 ... 0 1 3]

# %% [markdown]
# $ c=list, 设置cmap, 可以达到区分的目的 $
# https://matplotlib.org/2.0.2/examples/color/colormaps_reference.html

# %%
plt.figure(figsize=(15, 9))
plt.scatter(data[:,0], data[:, 1], c=y_hat, cmap='rainbow')
